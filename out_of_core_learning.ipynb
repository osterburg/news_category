# %%
import re
import sys
import csv
import random

import numpy as np
import pandas as pd

import dask
import dask.dataframe as dd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import HashingVectorizer, TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.pipeline import Pipeline

from pathlib import Path

from tqdm import tqdm
from wordcloud import WordCloud, STOPWORDS

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter("ignore")

# %%
train_file = 'data/train_categorical_data.csv'
test_file = 'data/test_categorical_data.csv'

# %%
# Getting 20% from the news content in the test data
num_lines = 0
with open(test_file, 'r') as f:
    for line in f:
        num_lines += 1

print('Number of lines: {}'.format(num_lines))

s = int(round(num_lines * 0.2))
# Out:
# Number of lines: 1625303

# %%
skip = sorted(random.sample(range(1, num_lines + 1), num_lines - s)) 
test_df = pd.read_csv(test_file, skiprows=skip)

# %%
validation_scores = []
training_set_size = []

# Build the vectorizer and the classifier
h_vectorizer = HashingVectorizer(encoding='latin-1')
clf = PassiveAggressiveClassifier(C=1)

# Extract the features for the validation once and for all
text_validation = test_df['news_content'].tolist()
target_validation = test_df['category'].tolist()

X_validation = h_vectorizer.transform(text_validation)
classes = np.arange(12) 

n_samples = 0
chunksize = 100
reader = pd.read_csv(train_file, chunksize=chunksize)

i = 0
for df in reader:
    # Get batch
    texts_in_batch = df['news_content'].tolist()
    targets_in_batch = df['category'].tolist()

    n_samples += len(texts_in_batch)

    # Vectorize the text in the batch
    X_batch = h_vectorizer.transform(texts_in_batch)

    # Incrementally train the model on the new batch
    clf.partial_fit(X_batch, targets_in_batch, classes=classes)

    if n_samples % 100 == 0:
        # Compute the validation score of the current state of the model
        score = clf.score(X_validation, target_validation)
        validation_scores.append(score)
        training_set_size.append(n_samples)

    if i % 100 == 0:
        print("n_samples: {0}, score: {1:.4f}".format(n_samples, score))

    i += 1
# Out:
# n_samples: 100, score: 0.2019
# n_samples: 10100, score: 0.2109
# n_samples: 20100, score: 0.2205
# n_samples: 30100, score: 0.2867
# n_samples: 40100, score: 0.3091
# n_samples: 50100, score: 0.2745
# n_samples: 60100, score: 0.3356
# n_samples: 70100, score: 0.3087
# n_samples: 80100, score: 0.2987
# n_samples: 90100, score: 0.2819
# n_samples: 100100, score: 0.3144
# n_samples: 110100, score: 0.2986
# n_samples: 120100, score: 0.3180
# n_samples: 130100, score: 0.3252
# n_samples: 140100, score: 0.3296
# n_samples: 150100, score: 0.3525
# n_samples: 160100, score: 0.3531
# n_samples: 170100, score: 0.3441
# n_samples: 180100, score: 0.3484
# n_samples: 190100, score: 0.3033
# n_samples: 200100, score: 0.3575
# n_samples: 210100, score: 0.3615
# n_samples: 220100, score: 0.3645
# n_samples: 230100, score: 0.3801
# n_samples: 240100, score: 0.3742
# n_samples: 250100, score: 0.3753
# n_samples: 260100, score: 0.3381
# n_samples: 270100, score: 0.3455
# n_samples: 280100, score: 0.4107
# n_samples: 290100, score: 0.4139
# n_samples: 300100, score: 0.4037
# n_samples: 310100, score: 0.4001
# n_samples: 320100, score: 0.4094
# n_samples: 330100, score: 0.3996
# n_samples: 340100, score: 0.3962
# n_samples: 350100, score: 0.3855
# n_samples: 360100, score: 0.3763
# n_samples: 370100, score: 0.3374
# n_samples: 380100, score: 0.3241
# n_samples: 390100, score: 0.4073
# n_samples: 400100, score: 0.4161
# n_samples: 410100, score: 0.3761
# n_samples: 420100, score: 0.3817
# n_samples: 430100, score: 0.3887
# n_samples: 440100, score: 0.3970
# n_samples: 450100, score: 0.4163
# n_samples: 460100, score: 0.3967
# n_samples: 470100, score: 0.3696
# n_samples: 480100, score: 0.4088
# n_samples: 490100, score: 0.3871
# n_samples: 500100, score: 0.3967
# n_samples: 510100, score: 0.3931
# n_samples: 520100, score: 0.3917
# n_samples: 530100, score: 0.3882
# n_samples: 540100, score: 0.3979
# n_samples: 550100, score: 0.3789
# n_samples: 560100, score: 0.3978
# n_samples: 570100, score: 0.3651
# n_samples: 580100, score: 0.3867
# n_samples: 590100, score: 0.3803
# n_samples: 600100, score: 0.3316
# n_samples: 610100, score: 0.3405
# n_samples: 620100, score: 0.3332
# n_samples: 630100, score: 0.3223
# n_samples: 640100, score: 0.3431
# n_samples: 650100, score: 0.3242
# n_samples: 660100, score: 0.3470
# n_samples: 670100, score: 0.3443
# n_samples: 680100, score: 0.3321
# n_samples: 690100, score: 0.3584
# n_samples: 700100, score: 0.3826
# n_samples: 710100, score: 0.3838
# n_samples: 720100, score: 0.3895
# n_samples: 730100, score: 0.3953
# n_samples: 740100, score: 0.3996
# n_samples: 750100, score: 0.3932
# n_samples: 760100, score: 0.3776
# n_samples: 770100, score: 0.3807
# n_samples: 780100, score: 0.3022
# n_samples: 790100, score: 0.3077
# n_samples: 800100, score: 0.3021
# n_samples: 810100, score: 0.3610
# n_samples: 820100, score: 0.3698
# n_samples: 830100, score: 0.3055
# n_samples: 840100, score: 0.2582
# n_samples: 850100, score: 0.2089
# n_samples: 860100, score: 0.2178
# n_samples: 870100, score: 0.2615
# n_samples: 880100, score: 0.2586
# n_samples: 890100, score: 0.1744
# n_samples: 900100, score: 0.2851
# n_samples: 910100, score: 0.2845
# n_samples: 920100, score: 0.2553
# n_samples: 930100, score: 0.2408
# n_samples: 940100, score: 0.2258
# n_samples: 950100, score: 0.3624
# n_samples: 960100, score: 0.3674
# n_samples: 970100, score: 0.3631
# n_samples: 980100, score: 0.3758
# n_samples: 990100, score: 0.3665
# n_samples: 1000100, score: 0.3514
# n_samples: 1010100, score: 0.4167
# n_samples: 1020100, score: 0.4162
# n_samples: 1030100, score: 0.3725
# n_samples: 1040100, score: 0.4209
# n_samples: 1050100, score: 0.4161
# n_samples: 1060100, score: 0.3721
# n_samples: 1070100, score: 0.4365
# n_samples: 1080100, score: 0.4327
# n_samples: 1090100, score: 0.4211
# n_samples: 1100100, score: 0.3161
# n_samples: 1110100, score: 0.3149
# n_samples: 1120100, score: 0.3122
# n_samples: 1130100, score: 0.3228
# n_samples: 1140100, score: 0.3245
# n_samples: 1150100, score: 0.3502
# n_samples: 1160100, score: 0.3996
# n_samples: 1170100, score: 0.3993
# n_samples: 1180100, score: 0.3422
# n_samples: 1190100, score: 0.3312
# n_samples: 1200100, score: 0.3477
# n_samples: 1210100, score: 0.4415
# n_samples: 1220100, score: 0.4602
# n_samples: 1230100, score: 0.4553
# n_samples: 1240100, score: 0.4425
# n_samples: 1250100, score: 0.4027
# n_samples: 1260100, score: 0.4229
# n_samples: 1270100, score: 0.4177
# n_samples: 1280100, score: 0.3962
# n_samples: 1290100, score: 0.4127
# n_samples: 1300100, score: 0.4311
# n_samples: 1310100, score: 0.3900
# n_samples: 1320100, score: 0.4675
# n_samples: 1330100, score: 0.4315
# n_samples: 1340100, score: 0.4395
# n_samples: 1350100, score: 0.4447
# n_samples: 1360100, score: 0.4060
# n_samples: 1370100, score: 0.2942
# n_samples: 1380100, score: 0.1876
# n_samples: 1390100, score: 0.1477
# n_samples: 1400100, score: 0.3222
# n_samples: 1410100, score: 0.3266
# n_samples: 1420100, score: 0.3307
# n_samples: 1430100, score: 0.4217
# n_samples: 1440100, score: 0.4436
# n_samples: 1450100, score: 0.3842
# n_samples: 1460100, score: 0.3936
# n_samples: 1470100, score: 0.4072
# n_samples: 1480100, score: 0.4277
# n_samples: 1490100, score: 0.4380
# n_samples: 1500100, score: 0.3946
# n_samples: 1510100, score: 0.3773
# n_samples: 1520100, score: 0.4052
# n_samples: 1530100, score: 0.4452
# n_samples: 1540100, score: 0.4427
# n_samples: 1550100, score: 0.4164
# n_samples: 1560100, score: 0.4109
# n_samples: 1570100, score: 0.4054
# n_samples: 1580100, score: 0.4715
# n_samples: 1590100, score: 0.3653
# n_samples: 1600100, score: 0.4248
# n_samples: 1610100, score: 0.3692
# n_samples: 1620100, score: 0.3702
# n_samples: 1630100, score: 0.4316
# n_samples: 1640100, score: 0.3789
# n_samples: 1650100, score: 0.3895
# n_samples: 1660100, score: 0.4209
# n_samples: 1670100, score: 0.4343
# n_samples: 1680100, score: 0.4514
# n_samples: 1690100, score: 0.4628
# n_samples: 1700100, score: 0.4503
# n_samples: 1710100, score: 0.3810
# n_samples: 1720100, score: 0.3879
# n_samples: 1730100, score: 0.4501
# n_samples: 1740100, score: 0.4593
# n_samples: 1750100, score: 0.4044
# n_samples: 1760100, score: 0.4224
# n_samples: 1770100, score: 0.4245
# n_samples: 1780100, score: 0.4612
# n_samples: 1790100, score: 0.4587
# n_samples: 1800100, score: 0.4473
# n_samples: 1810100, score: 0.3930
# n_samples: 1820100, score: 0.4155
# n_samples: 1830100, score: 0.4660
# n_samples: 1840100, score: 0.4303
# n_samples: 1850100, score: 0.4149
# n_samples: 1860100, score: 0.4137
# n_samples: 1870100, score: 0.4030
# n_samples: 1880100, score: 0.4349
# n_samples: 1890100, score: 0.4058
# n_samples: 1900100, score: 0.3948
# n_samples: 1910100, score: 0.4413
# n_samples: 1920100, score: 0.4252
# n_samples: 1930100, score: 0.4508
# n_samples: 1940100, score: 0.4758
# n_samples: 1950100, score: 0.4367
# n_samples: 1960100, score: 0.4415
# n_samples: 1970100, score: 0.4298
# n_samples: 1980100, score: 0.4309
# n_samples: 1990100, score: 0.4256
# n_samples: 2000100, score: 0.4233
# n_samples: 2010100, score: 0.4223
# n_samples: 2020100, score: 0.4312
# n_samples: 2030100, score: 0.4212
# n_samples: 2040100, score: 0.4391
# n_samples: 2050100, score: 0.4248
# n_samples: 2060100, score: 0.4270
# n_samples: 2070100, score: 0.4407
# n_samples: 2080100, score: 0.4286
# n_samples: 2090100, score: 0.4303
# n_samples: 2100100, score: 0.4226
# n_samples: 2110100, score: 0.4362
# n_samples: 2120100, score: 0.4597
# n_samples: 2130100, score: 0.4279
# n_samples: 2140100, score: 0.4143
# n_samples: 2150100, score: 0.4328
# n_samples: 2160100, score: 0.3956
# n_samples: 2170100, score: 0.3875
# n_samples: 2180100, score: 0.4019
# n_samples: 2190100, score: 0.4407
# n_samples: 2200100, score: 0.4127
# n_samples: 2210100, score: 0.4256
# n_samples: 2220100, score: 0.4214
# n_samples: 2230100, score: 0.4410
# n_samples: 2240100, score: 0.4593
# n_samples: 2250100, score: 0.4498
# n_samples: 2260100, score: 0.4265
# n_samples: 2270100, score: 0.4001
# n_samples: 2280100, score: 0.3825
# n_samples: 2290100, score: 0.3800
# n_samples: 2300100, score: 0.3969
# n_samples: 2310100, score: 0.3960
# n_samples: 2320100, score: 0.3695
# n_samples: 2330100, score: 0.3706
# n_samples: 2340100, score: 0.3684
# n_samples: 2350100, score: 0.3700
# n_samples: 2360100, score: 0.3754
# n_samples: 2370100, score: 0.3738
# n_samples: 2380100, score: 0.3974
# n_samples: 2390100, score: 0.4164
# n_samples: 2400100, score: 0.4011
# n_samples: 2410100, score: 0.3531
# n_samples: 2420100, score: 0.3521
# n_samples: 2430100, score: 0.3968
# n_samples: 2440100, score: 0.4023
# n_samples: 2450100, score: 0.3963
# n_samples: 2460100, score: 0.3915
# n_samples: 2470100, score: 0.4545
# n_samples: 2480100, score: 0.4471
# n_samples: 2490100, score: 0.4292
# n_samples: 2500100, score: 0.3918
# n_samples: 2510100, score: 0.4459
# n_samples: 2520100, score: 0.4098
# n_samples: 2530100, score: 0.4288
# n_samples: 2540100, score: 0.4313
# n_samples: 2550100, score: 0.4224
# n_samples: 2560100, score: 0.4171
# n_samples: 2570100, score: 0.4121
# n_samples: 2580100, score: 0.4159
# n_samples: 2590100, score: 0.4171
# n_samples: 2600100, score: 0.4279
# n_samples: 2610100, score: 0.4259
# n_samples: 2620100, score: 0.4393
# n_samples: 2630100, score: 0.4470
# n_samples: 2640100, score: 0.4543
# n_samples: 2650100, score: 0.4348
# n_samples: 2660100, score: 0.4531
# n_samples: 2670100, score: 0.4599
# n_samples: 2680100, score: 0.4695
# n_samples: 2690100, score: 0.4592
# n_samples: 2700100, score: 0.4536
# n_samples: 2710100, score: 0.4623
# n_samples: 2720100, score: 0.4649
# n_samples: 2730100, score: 0.4625
# n_samples: 2740100, score: 0.4592
# n_samples: 2750100, score: 0.4564
# n_samples: 2760100, score: 0.4526

# %%
plt.plot(training_set_size, validation_scores)
plt.xlabel("Number of samples")
plt.ylabel("Validation score")
plt.title('Progression of validation score with number of samples');
